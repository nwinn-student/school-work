# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv("/kaggle/input/crop-data-of-the-indian-states/Crop_Data.csv")
df.head()
# Out:
#            Crop       Season  State      Area      Soil Type Pesticide Usage  \
# 0  Cotton(lint)  Kharif       Assam    1739.0     Black Soil             low
# 1         Onion  Whole Year   Assam    7832.0  Alluvial Soil            high
# 2        Potato  Whole Year   Assam   75259.0  Laterile Soil             low
# 3          Rice  Autumn       Assam  607358.0  Alluvial Soil             low
# 4          Rice  Summer       Assam  174974.0     Black Soil            high
#
#         pH Temperature Fertilizer Usage        Price  Rainfall
# 0  Average      Medium             High  2490.092421    3373.2
# 1      Low         Low           Medium  2348.904922    3520.7
# 2  Average        High             High  2448.287513    2957.4
# 3      Low        High             High  2714.419518    3079.6
# 4      Low         Low              Low  2883.356997    2566.7

# %%
# Remove NaNs and duplicates
df = df.dropna()
df = df.drop_duplicates()

# %%
# We only want to consider the crop Potato
p = df.groupby(['Crop','Area','Soil Type','Pesticide Usage','pH','Temperature','Fertilizer Usage','Rainfall'])['Price'].sum()
p = p['Potato'].reset_index()
p
# Out:
#          Area        Soil Type Pesticide Usage       pH Temperature  \
# 0         3.0    Alluvial Soil            high     High      Medium
# 1         6.0  Red/Yellow Soil             low      Low      Medium
# 2         8.0  Red/Yellow Soil            high     High        High
# 3         9.0    Laterile Soil             low  Average         Low
# 4        16.0    Laterile Soil             low  Average        High
# ..        ...              ...             ...      ...         ...
# 623  571399.0    Alluvial Soil            high  Average        High
# 624  572826.0  Red/Yellow Soil            high      Low      Medium
# 625  575641.0  Red/Yellow Soil            high      Low        High
# 626  575668.0    Alluvial Soil             low      Low      Medium
# 627  612600.0    Alluvial Soil             low  Average        High
#
#     Fertilizer Usage  Rainfall        Price
# 0             Medium   1576.10  2194.615166
# 1                Low   1334.30  2809.892270
# 2             Medium   2674.20  2646.770204
# 3             Medium    729.10  2291.295777
# 4               High   1033.20  2132.876546
# ..               ...       ...          ...
# 623           Medium   1062.93  2962.032347
# 624             High   1565.24  2676.308471
# 625              Low   1321.30  2575.448101
# 626           Medium    795.40  2761.919820
# 627             High   3129.70  2392.026672
#
# [628 rows x 8 columns]

# %%
# Looks like PCA won't be good enough
'''
    We could look at Soil Type, Pesticide Usage, pH, Temperature, 
    Fertilizer Usage, and Rainfall to understand what countries believe
    to be the most efficient for growing potatoes.
    
    Exclude Rainfall and Area.
    
    Treemap idiom, we could use area instead or alongside rainfall too.
'''
# Out:
# '\n    We could look at Soil Type, Pesticide Usage, pH, Temperature, \n    Fertilizer Usage, and Rainfall to understand what countries believe\n    to be the most efficient for growing potatoes.\n    \n    Exclude Rainfall and Area.\n    \n    Treemap idiom, we could use area instead or alongside rainfall too.\n'

# %%
# We only want to consider the crop Potato
p = df.groupby(['Crop','Area','Soil Type','Pesticide Usage','pH','Temperature','Fertilizer Usage','Rainfall'])['Price'].sum()
p = p['Potato'].reset_index()

p.describe()
# Out:
#                 Area     Rainfall        Price
# count     628.000000   628.000000   628.000000
# mean    50009.913599  1482.237914  2546.680695
# std    116220.678503   856.141664   486.760086
# min         3.000000    92.700000  1063.000000
# 25%      2437.500000   854.240000  2294.948823
# 50%      6783.000000  1205.900000  2527.237254
# 75%     23598.250000  2031.162500  2732.530437
# max    612600.000000  5553.900000  4903.000000

# %%
k = pd.to_numeric(p['Rainfall'])
L = []

for i in k:
    if i >= 2338:
        L.append("High")
    elif i > 626 and i < 2338:
        L.append("Medium")
    else:
        L.append("Low")
        
p['Rainfall'] = pd.DataFrame(L, columns=['Rainfall'])
p
# Out:
#          Area        Soil Type Pesticide Usage       pH Temperature  \
# 0         3.0    Alluvial Soil            high     High      Medium
# 1         6.0  Red/Yellow Soil             low      Low      Medium
# 2         8.0  Red/Yellow Soil            high     High        High
# 3         9.0    Laterile Soil             low  Average         Low
# 4        16.0    Laterile Soil             low  Average        High
# ..        ...              ...             ...      ...         ...
# 623  571399.0    Alluvial Soil            high  Average        High
# 624  572826.0  Red/Yellow Soil            high      Low      Medium
# 625  575641.0  Red/Yellow Soil            high      Low        High
# 626  575668.0    Alluvial Soil             low      Low      Medium
# 627  612600.0    Alluvial Soil             low  Average        High
#
#     Fertilizer Usage Rainfall        Price
# 0             Medium   Medium  2194.615166
# 1                Low   Medium  2809.892270
# 2             Medium     High  2646.770204
# 3             Medium   Medium  2291.295777
# 4               High   Medium  2132.876546
# ..               ...      ...          ...
# 623           Medium   Medium  2962.032347
# 624             High   Medium  2676.308471
# 625              Low   Medium  2575.448101
# 626           Medium   Medium  2761.919820
# 627             High     High  2392.026672
#
# [628 rows x 8 columns]

# %%
# The dataset is still too large, so make a new smaller one

# we can reduce by combining and selecting a show number
# 5070 is one of the above, however we could randomize it OR create a treemap for all of 3640 to show the whole dataset
fd = p.groupby(['Soil Type','Pesticide Usage','pH','Temperature','Fertilizer Usage','Rainfall'])['Price'].mean().reset_index()
fd
# Out:
#            Soil Type Pesticide Usage       pH Temperature Fertilizer Usage  \
# 0      Alluvial Soil            high  Average        High             High
# 1      Alluvial Soil            high  Average        High              Low
# 2      Alluvial Soil            high  Average        High           Medium
# 3      Alluvial Soil            high  Average         Low             High
# 4      Alluvial Soil            high  Average         Low              Low
# ..               ...             ...      ...         ...              ...
# 322  Red/Yellow Soil             low      Low      Medium             High
# 323  Red/Yellow Soil             low      Low      Medium             High
# 324  Red/Yellow Soil             low      Low      Medium              Low
# 325  Red/Yellow Soil             low      Low      Medium              Low
# 326  Red/Yellow Soil             low      Low      Medium           Medium
#
#     Rainfall        Price
# 0     Medium  2318.595677
# 1     Medium  2334.431421
# 2     Medium  2874.595512
# 3        Low  2233.046569
# 4        Low  3070.194713
# ..       ...          ...
# 322     High  2344.814690
# 323   Medium  3041.260893
# 324      Low  2707.832731
# 325   Medium  2583.495032
# 326   Medium  2337.151811
#
# [327 rows x 7 columns]

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Soil Type         327 non-null    object
#  1   Pesticide Usage   327 non-null    object
#  2   pH                327 non-null    object
#  3   Temperature       327 non-null    object
#  4   Fertilizer Usage  327 non-null    object
#  5   Rainfall          327 non-null    object
#  6   Price             327 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 18.0+ KB

# %%
fig = px.treemap(fd, path=[px.Constant("all"), 'Soil Type', 'Pesticide Usage','pH','Temperature'], values='Price')
# Honestly, I wish that I could use the entire dataset, however I do know that the treemap may not even render

fig.update_traces(root_color="lightgrey")

fig.update_layout(
    updatemenus=[
        dict(buttons=list([
            dict(label="Pesticide Usage",
                 method="update",
                 args=[{"visible": [True, False, False, False]}
                      ]),
            dict(label="pH",
                 method="update",
                 args=[{"visible": [False, False, True, False]},
                       ]),
            dict(label="Temperature",
                 method="update",
                 args=[{"visible": [True, False, True, False]}]),
            dict(label="Fertilizer Usage",
                 method="update",
                 args=[{"visible": [True, False, True, False]}]),
            dict(label="All",
                 method="update",
                 args=[{"visible": [True, False, True, False]}])
        ]),
        )
    ]
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="de843e0f-f0e3-423e-8020-12afbc9764f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de843e0f-f0e3-423e-8020-12afbc9764f5")) {                    Plotly.newPlot(                        "de843e0f-f0e3-423e-8020-12afbc9764f5",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ePrice=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["all\u002fAlluvial Soil\u002fhigh\u002fAverage\u002fHigh","all\u002fBlack Soil\u002fhigh\u002fAverage\u002fHigh","all\u002fLaterile Soil\u002fhigh\u002fAverage\u002fHigh","all\u002fRed\u002fYellow Soil\u002fhigh\u002fAverage\u002fHigh","all\u002fAlluvial Soil\u002flow\u002fAverage\u002fHigh","all\u002fBlack Soil\u002flow\u002fAverage\u002fHigh","all\u002fLaterile Soil\u002flow\u002fAverage\u002fHigh","all\u002fRed\u002fYellow Soil\u002flow\u002fAverage\u002fHigh","all\u002fAlluvial Soil\u002fhigh\u002fHigh\u002fHigh","all\u002fBlack Soil\u002fhigh\u002fHigh\u002fHigh","all\u002fLaterile Soil\u002fhigh\u002fHigh\u002fHigh","all\u002fRed\u002fYellow Soil\u002fhigh\u002fHigh\u002fHigh","all\u002fAlluvial Soil\u002flow\u002fHigh\u002fHigh","all\u002fBlack Soil\u002flow\u002fHigh\u002fHigh","all\u002fLaterile Soil\u002flow\u002fHigh\u002fHigh","all\u002fRed\u002fYellow Soil\u002flow\u002fHigh\u002fHigh","all\u002fAlluvial Soil\u002fhigh\u002fLow\u002fHigh","all\u002fBlack Soil\u002fhigh\u002fLow\u002fHigh","all\u002fLaterile Soil\u002fhigh\u002fLow\u002fHigh","all\u002fRed\u002fYellow Soil\u002fhigh\u002fLow\u002fHigh","all\u002fAlluvial Soil\u002flow\u002fLow\u002fHigh","all\u002fBlack Soil\u002flow\u002fLow\u002fHigh","all\u002fLaterile Soil\u002flow\u002fLow\u002fHigh","all\u002fRed\u002fYellow Soil\u002flow\u002fLow\u002fHigh","all\u002fAlluvial Soil\u002fhigh\u002fAverage\u002fLow","all\u002fBlack Soil\u002fhigh\u002fAverage\u002fLow","all\u002fLaterile Soil\u002fhigh\u002fAverage\u002fLow","all\u002fRed\u002fYellow Soil\u002fhigh\u002fAverage\u002fLow","all\u002fAlluvial Soil\u002flow\u002fAverage\u002fLow","all\u002fBlack Soil\u002flow\u002fAverage\u002fLow","all\u002fLaterile Soil\u002flow\u002fAverage\u002fLow","all\u002fRed\u002fYellow Soil\u002flow\u002fAverage\u002fLow","all\u002fAlluvial Soil\u002fhigh\u002fHigh\u002fLow","all\u002fBlack Soil\u002fhigh\u002fHigh\u002fLow","all\u002fLaterile Soil\u002fhigh\u002fHigh\u002fLow","all\u002fRed\u002fYellow Soil\u002fhigh\u002fHigh\u002fLow","all\u002fAlluvial Soil\u002flow\u002fHigh\u002fLow","all\u002fBlack Soil\u002flow\u002fHigh\u002fLow","all\u002fLaterile Soil\u002flow\u002fHigh\u002fLow","all\u002fRed\u002fYellow Soil\u002flow\u002fHigh\u002fLow","all\u002fAlluvial Soil\u002fhigh\u002fLow\u002fLow","all\u002fBlack Soil\u002fhigh\u002fLow\u002fLow","all\u002fLaterile Soil\u002fhigh\u002fLow\u002fLow","all\u002fRed\u002fYellow Soil\u002fhigh\u002fLow\u002fLow","all\u002fAlluvial Soil\u002flow\u002fLow\u002fLow","all\u002fBlack Soil\u002flow\u002fLow\u002fLow","all\u002fLaterile Soil\u002flow\u002fLow\u002fLow","all\u002fRed\u002fYellow Soil\u002flow\u002fLow\u002fLow","all\u002fAlluvial Soil\u002fhigh\u002fAverage\u002fMedium","all\u002fBlack Soil\u002fhigh\u002fAverage\u002fMedium","all\u002fLaterile Soil\u002fhigh\u002fAverage\u002fMedium","all\u002fRed\u002fYellow Soil\u002fhigh\u002fAverage\u002fMedium","all\u002fAlluvial Soil\u002flow\u002fAverage\u002fMedium","all\u002fBlack Soil\u002flow\u002fAverage\u002fMedium","all\u002fLaterile Soil\u002flow\u002fAverage\u002fMedium","all\u002fRed\u002fYellow Soil\u002flow\u002fAverage\u002fMedium","all\u002fAlluvial Soil\u002fhigh\u002fHigh\u002fMedium","all\u002fBlack Soil\u002fhigh\u ...

# %%
# Source: https://github.com/lforeman2/plotlyDropDownMenu/blob/main/plotlyDemo_groupedHistogram.ipynb

title="Soil vs "

plotColumns = ['Pesticide Usage','pH','Temperature','Fertilizer Usage','Rainfall']

traces = []
buttons = []
m=0
for i, col in enumerate(plotColumns):
    visible = [False] * len(plotColumns)
    name=col
    
    traces.append(
        px.treemap(
                fd, 
                path=[px.Constant("all"), 'Soil Type', name], 
                values='Price',
            ).data[0]
        )
    visible[m] = True
    m+=1
    buttons.append(dict(label=name,
                        method="update",
                        args=[{"visible":visible},
                              {"title":f"{(title+name+' affect on Potato Prices')}"}]))

updatemenus = [{'active':4, "buttons":buttons}]


#print(traces)

fig = go.Figure(data=traces,
                 layout=dict(updatemenus=updatemenus))
fig.update_layout(title=title+"Rainfall affect on Potato Prices", barmode='overlay')
fig.show()
fig.write_html("demowidget.html")
# Out:
# <div>                            <div id="0c035671-7736-41fe-9c63-1678b672374b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0