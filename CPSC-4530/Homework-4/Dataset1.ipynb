# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px

df = pd.read_csv("/kaggle/input/200000-jeopardy-questions/JEOPARDY_CSV.csv")
df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1    Air Date    216930 non-null  object
#  2    Round       216930 non-null  object
#  3    Category    216930 non-null  object
#  4    Value       213296 non-null  object
#  5    Question    216930 non-null  object
#  6    Answer      216927 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 11.6+ MB

# %%
df.describe()
# Out:
#          Show Number
# count  216930.000000
# mean     4264.238519
# std      1386.296335
# min         1.000000
# 25%      3349.000000
# 50%      4490.000000
# 75%      5393.000000
# max      6300.000000

# %%
df.columns = df.columns.str.strip()

# %%
# Removes the NaNs and duplicates
df = df.dropna()
df = df.drop_duplicates()

# Change Value to number
df['Value'] = df['Value'].str.replace("$","")
df['Value'] = df['Value'].str.replace(",","")
df['Value'] = df['Value'].astype(int)

df
# Out:
#         Show Number    Air Date             Round  \
# 0              4680  2004-12-31         Jeopardy!
# 1              4680  2004-12-31         Jeopardy!
# 2              4680  2004-12-31         Jeopardy!
# 3              4680  2004-12-31         Jeopardy!
# 4              4680  2004-12-31         Jeopardy!
# ...             ...         ...               ...
# 216924         4999  2006-05-11  Double Jeopardy!
# 216925         4999  2006-05-11  Double Jeopardy!
# 216926         4999  2006-05-11  Double Jeopardy!
# 216927         4999  2006-05-11  Double Jeopardy!
# 216928         4999  2006-05-11  Double Jeopardy!
#
#                                Category  Value  \
# 0                               HISTORY    200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES    200
# 2           EVERYBODY TALKS ABOUT IT...    200
# 3                      THE COMPANY LINE    200
# 4                   EPITAPHS & TRIBUTES    200
# ...                                 ...    ...
# 216924                     OFF-BROADWAY   2000
# 216925                   RIDDLE ME THIS   2000
# 216926                        "T" BIRDS   2000
# 216927           AUTHORS IN THEIR YOUTH   2000
# 216928                       QUOTATIONS   2000
#
#                                                  Question        Answer
# 0       For the last 8 years of his life, Galileo was ...    Copernicus
# 1       No. 2: 1912 Olympian; football star at Carlisl...    Jim Thorpe
# 2       The city of Yuma in this state has a record av...       Arizona
# 3       In 1963, live on "The Art Linkletter Show", th...    McDonald's
# 4       Signer of the Dec. of Indep., framer of the Co...    John Adams
# ...                                                   ...           ...
# 216924  In 2006 the cast of this long-running hit emba...         Stomp
# 216925  This Puccini opera turns on the solution to 3 ...      Turandot
# 216926  In North America this term is properly applied...    a titmouse
# 216927  In Penny Lane, where this "Hellraiser" grew up...  Clive Barker
# 216928  From Ft. Sill, Okla. he made the plea, Arizona...      Geronimo
#
# [213293 rows x 7 columns]

# %%
df['Show Number'].unique()
# Out:
# array([4680, 5957, 3751, ..., 5070, 5195, 4999])

# %%
df['Show Number'].nunique()
# Out:
# 3640

# %%
# The dataset is still too large, so make a new smaller one

# we can reduce by combining and selecting a show number
# 5070 is one of the above, however we could randomize it OR create a treemap for all of 3640 to show the whole dataset
p = df.groupby(['Show Number','Category','Answer'])['Value'].sum()
p = p[5070].reset_index()

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  60 non-null     object
#  1   Answer    60 non-null     object
#  2   Value     60 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.5+ KB

# %%
# Honestly, I wish that I could use the entire dataset, however I do know that the treemap may not even render
fig = px.treemap(p, path=[px.Constant("all"), 'Category', 'Answer'], values='Value')
fig.update_traces(root_color="lightgrey")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="904fd113-dc75-4a09-80f2-a221c39a767d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("904fd113-dc75-4a09-80f2-a221c39a767d")) {                    Plotly.newPlot(                        "904fd113-dc75-4a09-80f2-a221c39a767d",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eValue=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["all\u002fTALES OF E.T.A. HOFFMANN\u002f(Carl) Jung","all\u002fSIGNING OFF\u002f(John) Hancock","all\u002fANIMATION\u002fAshton Kutcher","all\u002fTALES OF E.T.A. HOFFMANN\u002fAtlantis","all\u002fANCIENT HISTORY\u002fAttila the Hun","all\u002fIT'S A MONARCHY\u002fBhutan","all\u002fTHE NATIONAL PARK SYSTEM\u002fCape Hatteras or Cape Lookout","all\u002fSPOKES-CHARACTERS\u002fCheetos","all\u002fADJECTIVES\u002fClement","all\u002fIT'S A MONARCHY\u002fDenmark","all\u002fWAR MOVIE LOCATIONS\u002fGrenada","all\u002fSIGNING OFF\u002fJimmy Hoffa","all\u002fIT'S A MONARCHY\u002fJordan","all\u002fSIGNING OFF\u002fKellogg","all\u002fWAR MOVIE LOCATIONS\u002fKorea","all\u002fIT'S A MONARCHY\u002fMalaysia","all\u002fSIGNING OFF\u002fMichelangelo (Buonarroti)","all\u002fANCIENT HISTORY\u002fOlympiads","all\u002fWAR MOVIE LOCATIONS\u002fRussia","all\u002fIT'S A MONARCHY\u002fSamoa","all\u002fSPOKES-CHARACTERS\u002fSnuggle (fabric softener)","all\u002fWAR MOVIE LOCATIONS\u002fSpain","all\u002fTHE NATIONAL PARK SYSTEM\u002fTeddy Roosevelt","all\u002fTALES OF E.T.A. HOFFMANN\u002fThe Nutcracker","all\u002fSPOKES-CHARACTERS\u002fTony the Tiger (Tony Tiger accepted)","all\u002fANCIENT HISTORY\u002fWessex","all\u002f3-LETTER WORDS\u002fa Wat","all\u002f\"U\"-ENDING CREATURES\u002fa caribou","all\u002fTALES OF E.T.A. HOFFMANN\u002fa cat","all\u002fANIMATION\u002fa cel","all\u002fSPOKES-CHARACTERS\u002fa giraffe","all\u002f\"U\"-ENDING CREATURES\u002fa kinkajou","all\u002fYOGA\u002fa mat","all\u002f3-LETTER WORDS\u002fa pod","all\u002fANCIENT HISTORY\u002fa pyramid (the pyramids accepted)","all\u002f3-LETTER WORDS\u002fa vas","all\u002f\"U\"-ENDING CREATURES\u002fa zebu","all\u002f3-LETTER WORDS\u002fan awl","all\u002f\"U\"-ENDING CREATURES\u002fan emu","all\u002fYOGA\u002fbreathing","all\u002fYOGA\u002fchild's pose","all\u002fANIMATION\u002fcomputer generated","all\u002fADJECTIVES\u002ffair","all\u002f\"U\"-ENDING CREATURES\u002ffugu","all\u002fTHE NATIONAL PARK SYSTEM\u002fglaciers","all\u002fTALES OF E.T.A. HOFFMANN\u002fhis shadow","all\u002fYOGA\u002fnamaste","all\u002fADJECTIVES\u002fodd","all\u002fANIMATION\u002fsound effects","all\u002fADJECTIVES\u002fstraight","all\u002fANCIENT HISTORY\u002fthe Incas","all\u002fTHE NATIONAL PARK SYSTEM\u002fthe Navajo tribe","all\u002fWAR MOVIE LOCATIONS\u002fthe Philippines","all\u002fSPOKES-CHARACTERS\u002fthe Pillsbury Doughboy","all\u002fTHE NATIONAL PARK SYSTEM\u002fthe Snake River","all\u002fSIGNING OFF\u002fthe Treaty of Versailles","all\u002fANIMATION\u002fthe background","all\u002f3-LETTER WORDS\u002fthe bib","all\u002fYOGA\u002fthe eye","all\u002fADJECTIVES\u002fvacant","all\u002f\"U\"-ENDING CREATURES","all\u002f3-LETTER WORDS","all\u002fADJECTIVES","all\u002fANCIENT HISTORY","all\u002fANIMATION","all\u002fIT'S A MONARCHY","all\u002fSIGNING OFF","all\u002fSPOKES-CHARACTERS","all\u002fTALES OF E.T.A. HOFFMANN","all\u002fTHE NATIONAL PARK SYSTEM","all\u002fWAR MOVIE LOCATIONS","all\u002fYOGA","all"],"labels":["(Carl) Jung","(John) Hancock","Ashton Kutcher","Atlantis","Attila the Hun","Bhutan","Cape Hatteras or Cape Lookout","Cheetos","Clement","Denmark","Grenada","Jimmy Hoffa","Jordan","Kellogg","Korea","Malaysia","Michelangelo (Buonarroti)","Olympiads","Rus ...
